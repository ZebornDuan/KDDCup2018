# %%
import seaborn
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:/Users/PC/Desktop/London/London_historical_aqi_forecast_stations_20180331.csv')
data.dtypes
# Out:
# MeasurementDateGMT     object
# station_id             object
# PM2.5 (ug/m3)         float64
# PM10 (ug/m3)          float64
# NO2 (ug/m3)           float64
# dtype: object

# %%
data.describe()
# Out:
#        PM2.5 (ug/m3)   PM10 (ug/m3)    NO2 (ug/m3)
# count  122985.000000  127108.000000  116216.000000
# mean       13.234925      21.013378      43.256648
# std        11.102862      14.280799      28.549720
# min       -10.500000     -11.800000      -4.700000
# 25%         6.400000      11.800000      21.600000
# 50%        10.200000      17.500000      37.800000
# 75%        16.400000      26.300000      58.400000
# max       189.700000     667.100000     336.100000

# %%
data.isnull().any()
# Out:
# MeasurementDateGMT    False
# station_id            False
# PM2.5 (ug/m3)          True
# PM10 (ug/m3)           True
# NO2 (ug/m3)            True
# dtype: bool

# %%
data = data.dropna(thresh=3)
data
# Out:
#        MeasurementDateGMT station_id  PM2.5 (ug/m3)  PM10 (ug/m3)  NO2 (ug/m3)
# 0           2017/1/1 0:00        CD1           40.0          44.4         36.6
# 1           2017/1/1 1:00        CD1           31.6          34.4         46.2
# 2           2017/1/1 2:00        CD1           24.7          28.1         38.3
# 3           2017/1/1 3:00        CD1           21.2          24.5         32.8
# 4           2017/1/1 4:00        CD1           24.9          23.0         28.1
# 5           2017/1/1 5:00        CD1           24.6          23.9         29.3
# 6           2017/1/1 6:00        CD1           23.9          22.0         28.8
# 7           2017/1/1 7:00        CD1           22.0          22.9         34.6
# 8           2017/1/1 8:00        CD1           19.0          20.1         44.6
# 9           2017/1/1 9:00        CD1           19.9          24.4         55.3
# 10         2017/1/1 10:00        CD1           16.6          17.5         46.4
# ...

# %%
data[['PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'NO2 (ug/m3)']] = data[['PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'NO2 (ug/m3)']].fillna(data[['PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'NO2 (ug/m3)']].mean())
# air_quality.describe()
data
# Out:
# e:\python3.6\lib\site-packages\pandas\core\frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
#        MeasurementDateGMT station_id  PM2.5 (ug/m3)  PM10 (ug/m3)  NO2 (ug/m3)
# 0           2017/1/1 0:00        CD1           40.0          44.4         36.6
# 1           2017/1/1 1:00        CD1           31.6          34.4         46.2
# 2           2017/1/1 2:00        CD1           24.7          28.1         38.3
# 3           2017/1/1 3:00        CD1           21.2          24.5         32.8
# 4           2017/1/1 4:00        CD1           24.9          23.0         28.1
# 5           2017/1/1 5:00        CD1           24.6          23.9         29.3
# ...

# %%
data.to_csv('C:/Users/PC/Desktop/London/London_historical_aqi_forecast_stations_20180331_cleaned.csv', index=False)
