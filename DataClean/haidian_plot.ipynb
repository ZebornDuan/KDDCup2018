# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

weather_data = pd.read_csv('E:/Working/DataMining/beijing_17_18_meo_cleaned.csv')
weather_data['station_id'].value_counts()
# Out:
# chaoyang_meo       8781
# pingchang_meo      8781
# daxing_meo         8781
# fangshan_meo       8781
# shunyi_meo         8781
# shijingshan_meo    8781
# yanqing_meo        8781
# zhaitang_meo       8781
# shangdianzi_meo    8781
# miyun_meo          8781
# hadian_meo         8780
# mentougou_meo      8780
# xiayunling_meo     8780
# fengtai_meo        8780
# huairou_meo        8780
# tongzhou_meo       8780
# pinggu_meo         8779
# beijing_meo        8778
# Name: station_id, dtype: int64

# %%
haidian = pd.DataFrame(weather_data[weather_data.station_id=='hadian_meo'])
temperature = haidian['temperature']
sns.distplot(temperature)
plt.show()

# %%
pressure = haidian['pressure']
sns.distplot(pressure)
plt.show()

# %%
humidity = haidian['humidity']
sns.distplot(humidity)
plt.show()

# %%
wind_direction = haidian['wind_direction']
sns.distplot(wind_direction)
plt.show()

# %%
wind_speed = haidian['wind_speed']
sns.distplot(wind_speed)
plt.show()
